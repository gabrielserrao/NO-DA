# %%
# load /samoa/data/smrserraoseabr/NO-DA/historymatching/ESMDA/KALMANGAIN_simulations_Loc_None_PERM_Nit4_HF100_PX0/it0/K_0.pkl
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# Load the data
df = pd.read_pickle('/samoa/data/smrserraoseabr/NO-DA/historymatching/ESMDA/filterdata_REF1000_PARALLEL_simulations_Loc_None_PERM_Nit4_HF100_PX0/it0/K_0.pkl')
K = np.array(df)
K = K.reshape(32,32,240)
plt.imshow(K[:,:,1])
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 7
#       4 import matplotlib.pyplot as plt
#       6 # Load the data
# ----> 7 df = pd.read_pickle('/samoa/data/smrserraoseabr/NO-DA/historymatching/ESMDA/filterdata_REF1000_PARALLEL_simulations_Loc_None_PERM_Nit4_HF100_PX0/it0/K_0.pkl')
#       8 K = np.array(df)
#       9 K = K.reshape(32,32,240)
#
# File /samoa/data/smrserraoseabr/.conda_samoa/envs/py310/lib/python3.10/site-packages/pandas/io/pickle.py:179, in read_pickle(filepath_or_buffer, compression, storage_options)
#     115 """
#     116 Load pickled pandas object (or any object) from file.
#     117
#    (...)
#     176 4    4    9
#     177 """
#     178 excs_to_catch = (AttributeError, ImportError, ModuleNotFoundError, TypeError)
# --> 179 with get_handle(
#     180     filepath_or_buffer,
#     181     "rb",
#     182     compression=compression,
# ...

# %%
import ipywidgets as widgets
from IPython.display import display

# %%
def plot_slice(slice_number):
    plt.imshow(K[:,:,slice_number])
    plt.colorbar()
    plt.show()

# Create a widget to select the slice
slice_slider = widgets.IntSlider(min=0, max=243, step=1, value=0, description='Slice:')

# Use the widget to interact with the plot
widgets.interact(plot_slice, slice_number=slice_slider)
# Out:
# interactive(children=(IntSlider(value=0, description='Slice:', max=243), Output()), _dom_classes=('widget-inte…
# <function __main__.plot_slice(slice_number)>

# %%
df
# Out:
#       0         1         2         3         4         5         6    \
# 0     0.0 -0.005699 -0.000278  0.004993  0.008460  0.010428  0.011334
# 1     0.0 -0.002834  0.003470  0.009359  0.013211  0.015252  0.015957
# 2     0.0 -0.000191  0.005910  0.010719  0.013390  0.014458  0.014454
# 3     0.0 -0.003357 -0.002702 -0.000433  0.001700  0.003311  0.004396
# 4     0.0 -0.002379 -0.002148  0.000132  0.002452  0.004258  0.005507
# ...   ...       ...       ...       ...       ...       ...       ...
# 1019  0.0  0.008141  0.007601  0.005243  0.003456  0.002488  0.002162
# 1020  0.0 -0.001668 -0.003229 -0.003073 -0.001891 -0.000291  0.001368
# 1021  0.0  0.002063  0.000292 -0.000383  0.000110  0.001199  0.002462
# 1022  0.0  0.001911 -0.001054 -0.002910 -0.003497 -0.003273 -0.002603
# 1023  0.0 -0.000777 -0.002552 -0.003392 -0.003301 -0.002657 -0.001754
#
#            7         8         9    ...       234       235       236  \
# ...

# %%
def plot_slice(slice_number):
    plt.imshow(K_None[:,:,slice_number])
    plt.colorbar()
    plt.show()

# Create a widget to select the slice
slice_slider = widgets.IntSlider(min=0, max=243, step=1, value=0, description='Slice:')

# Use the widget to interact with the plot
widgets.interact(plot_slice, slice_number=slice_slider)
# Out:
# interactive(children=(IntSlider(value=0, description='Slice:', max=243), Output()), _dom_classes=('widget-inte…
# <function __main__.plot_slice(slice_number)>

# %%
def plot_slice(slice_number):
    plt.imshow(K_GaspariCohn[:,:,slice_number])
    plt.colorbar()
    plt.show()

# Create a widget to select the slice
slice_slider = widgets.IntSlider(min=0, max=243, step=1, value=0, description='Slice:')

# Use the widget to interact with the plot
widgets.interact(plot_slice, slice_number=slice_slider)
# Out:
# interactive(children=(IntSlider(value=0, description='Slice:', max=243), Output()), _dom_classes=('widget-inte…
# <function __main__.plot_slice(slice_number)>

# %%
def plot_slice(slice_number):
    plt.imshow(K_Correlation[:,:,slice_number])
    plt.colorbar()
    plt.show()

# Create a widget to select the slice
slice_slider = widgets.IntSlider(min=0, max=243, step=1, value=0, description='Slice:')

# Use the widget to interact with the plot
widgets.interact(plot_slice, slice_number=slice_slider)
# Out:
# interactive(children=(IntSlider(value=0, description='Slice:', max=243), Output()), _dom_classes=('widget-inte…
# <function __main__.plot_slice(slice_number)>

# %%
rows = 16
cols = 16
fig, axes = plt.subplots(rows, cols, figsize=(20, 20))

for i in range(rows):
    for j in range(cols):
        slice_number = i * cols + j
        if slice_number < 244:
            axes[i, j].imshow(K[:,:,slice_number])
            axes[i, j].axis('off')

plt.show()

# %%
#plot the mean Kalman gain matrix of all slice number K[:,:,slice_number]

K = K.reshape(32,32,244)
plt.imshow(np.mean(K[:,:,:],axis=2))
plt.colorbar()

# %%
# Load the data
df_None = pd.read_pickle('/samoa/data/smrserraoseabr/NO-DA/historymatching/ESMDA/KALMANGAIN_simulations_Loc_None_PERM_Nit4_HF100_PX0/it0/K_0.pkl')
K_None = np.array(df_None)
K_None = K_None.reshape(32,32,244)

df_GaspariCohn = pd.read_pickle('/samoa/data/smrserraoseabr/NO-DA/historymatching/ESMDA/KALMANGAIN_simulations_Loc_GaspariCohn_PERM_Nit4_HF100_PX0/it0/K_0.pkl')
K_GaspariCohn = np.array(df_GaspariCohn)
K_GaspariCohn = K_GaspariCohn.reshape(32,32,244)

df_Correlation = pd.read_pickle('/samoa/data/smrserraoseabr/NO-DA/historymatching/ESMDA/KALMANGAIN_simulations_Loc_Correlation_PERM_Nit4_HF100_PX0/it0/K_0.pkl')
K_Correlation = np.array(df_Correlation)
K_Correlation = K_Correlation.reshape(32,32,244)

# %%
fig = plt.figure(figsize=(15,5))

ax1 = fig.add_subplot(131)
ax1.set_title('Kalman Gain')
im1 = ax1.imshow(np.mean(K_None[:,:,:],axis=2),cmap='jet')
plt.colorbar(im1, ax=ax1)

ax2 = fig.add_subplot(132)
ax2.set_title('GaspariCohn')
im2 = ax2.imshow(np.mean(K_GaspariCohn[:,:,:],axis=2),cmap='jet')
plt.colorbar(im2, ax=ax2)

ax3 = fig.add_subplot(133)
ax3.set_title('Correlation based on proxy')
im3 = ax3.imshow(np.mean(K_Correlation[:,:,:],axis=2),cmap='jet')
plt.colorbar(im3, ax=ax3)

plt.show()

# %%
mobj_7 = pd.read_pickle('/samoa/data/smrserraoseabr/NO-DA/historymatching/ESMDA/simulations_PERM_Nit8_HF100_PX0/it7/MObj_7.pkl')
mobj_0 = pd.read_pickle('/samoa/data/smrserraoseabr/NO-DA/historymatching/ESMDA/simulations_PERM_Nit8_HF100_PX0/it0/MObj_0.pkl')

# %%
mobj_7 = np.array(mobj_7)
mobj_0 = np.array(mobj_0)

# %%
np.mean(mobj_0)/244
# Out:
# 37.67578907356888

# %%
np.mean(mobj_7)/244
# Out:
# 10.97944576880971

# %%
M = pd.read_pickle(f'/samoa/data/smrserraoseabr/NO-DA/historymatching/ESMDA/filterdata_REF1000_PARALLEL_simulations_Loc_None_PERM_Nit8_HF100_PX0/it3/MGrid_3.pkl')
M_Prior = pd.read_pickle('/samoa/data/smrserraoseabr/NO-DA/historymatching/ESMDA/filterdata_REF1000_PARALLEL_simulations_Loc_None_PERM_Nit8_HF100_PX0/it0/MGrid_0.pkl')
M= np.exp(np.array(M).reshape(32,32,100))
M_Prior= np.exp(np.array(M_Prior).reshape(32,32,100))
#no exp
#M= np.array(M).reshape(32,32,100)
#M_Prior= np.array(M_Prior).reshape(32,32,100)

# %%
#plot M and M_Prior side by side
sample = 50
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.imshow(M[:,:,sample], cmap='jet')
plt.colorbar()
plt.title('M')
plt.subplot(1,2,2)
plt.imshow(M_Prior[:,:,sample], cmap='jet')
plt.colorbar()
plt.title('M_prior')
plt.show()


#plot the histogram bello each map
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.hist(M[:,:,sample].flatten(), bins=50)
plt.title('M')
plt.subplot(1,2,2)
plt.hist(M_Prior[:,:,sample].flatten(), bins=50)
plt.title('M_prior')
plt.show()

#print the statistics of each map
print('M')
print('mean: ', np.mean(M[:,:,sample]))
print('std: ', np.std(M[:,:,sample]))
print('M_prior')
print('mean: ', np.mean(M_Prior[:,:,sample]))
print('std: ', np.std(M_Prior[:,:,sample]))
# Out:
# M
# mean:  0.4449261164230959
# std:  2.399514673101374
# M_prior
# mean:  0.7454460534660697
# std:  2.5161261458694995

# %%
from scipy.stats import boxcox

# Assuming your data is in a one-dimensional array or list named "data"
data_transformed, lambda_best_fit = boxcox(M.flatten())

# data_transformed now contains the transformed data
# lambda_best_fit is the best-fit value for lambda

#plot the histogram of the transformed data
plt.hist(data_transformed, bins=20)
plt.show()

# %%
from scipy.special import inv_boxcox

# Using the transformed data and the lambda value found earlier
data_recovered = inv_boxcox(data_transformed, lambda_best_fit)

# %%
#compare the M hist with the data_recovered hist

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.hist(data_recovered,bins=50,label='data_recovered')
plt.legend()
plt.subplot(1,2,2)
plt.hist(M,bins=50,label='M')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 8
#       6 plt.legend()
#       7 plt.subplot(1,2,2)
# ----> 8 plt.hist(M,bins=50,label='M')
#       9 plt.legend()
#
# File /samoa/data/smrserraoseabr/.conda_samoa/envs/py310/lib/python3.10/site-packages/matplotlib/pyplot.py:2645, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2639 @_copy_docstring_and_deprecators(Axes.hist)
#    2640 def hist(
#    2641         x, bins=None, range=None, density=False, weights=None,
#    2642         cumulative=False, bottom=None, histtype='bar', align='mid',
#    2643         orientation='vertical', rwidth=None, log=False, color=None,
#    2644         label=None, stacked=False, *, data=None, **kwargs):
# -> 2645     return gca().hist(
# ...

# %%
plt.imshow(np.exp(M[:,:,3]))
#set limits
plt.clim(0,100)
plt.colorbar()

# %%
#plot  a histogram of M side to side with np.exp(M)
plt.hist(M.flatten(), bins=50)
# Out:
# (array([1.0000e+01, 2.4000e+01, 1.5200e+02, 6.6600e+02, 7.3760e+03,
#         1.3636e+04, 9.1480e+03, 8.0280e+03, 7.2740e+03, 6.7660e+03,
#         6.3740e+03, 5.8450e+03, 5.5390e+03, 4.9960e+03, 4.4190e+03,
#         3.7720e+03, 3.3080e+03, 2.8360e+03, 2.3330e+03, 1.8600e+03,
#         1.5180e+03, 1.2050e+03, 1.0260e+03, 8.4600e+02, 7.2900e+02,
#         5.3100e+02, 4.0400e+02, 3.7200e+02, 2.8500e+02, 1.9200e+02,
#         1.9100e+02, 1.4700e+02, 1.0900e+02, 9.2000e+01, 1.0100e+02,
#         5.8000e+01, 4.8000e+01, 4.3000e+01, 2.5000e+01, 2.2000e+01,
#         2.4000e+01, 1.9000e+01, 1.7000e+01, 1.2000e+01, 4.0000e+00,
#         7.0000e+00, 5.0000e+00, 2.0000e+00, 2.0000e+00, 2.0000e+00]),
#  array([-4.010015  , -3.19279204, -2.37556907, -1.5583461 , -0.74112314,
#          0.07609983,  0.8933228 ,  1.71054576,  2.52776873,  3.3449917 ,
#          4.16221466,  4.97943763,  5.7966606 ,  6.61388356,  7.43110653,
# ...

# %%
plt.hist(np.exp(M).flatten(), bins=50)
# Out:
# (array([1.01729e+05, 4.13000e+02, 1.14000e+02, 5.30000e+01, 2.60000e+01,
#         2.10000e+01, 1.60000e+01, 1.00000e+01, 3.00000e+00, 5.00000e+00,
#         2.00000e+00, 1.00000e+00, 0.00000e+00, 0.00000e+00, 1.00000e+00,
#         0.00000e+00, 1.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 1.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 2.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 2.00000e+00]),
#  array([6.55586470e-07, 3.19210197e+02, 6.38420394e+02, 9.57630591e+02,
#         1.27684079e+03, 1.59605098e+03, 1.91526118e+03, 2.23447138e+03,
#         2.55368157e+03, 2.87289177e+03, 3.19210197e+03, 3.51131217e+03,
# ...

# %%
np.exp(M).max()
# Out:
# 15960.509839366649
